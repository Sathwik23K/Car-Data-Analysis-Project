# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathwik23K/Car-Data-Analysis-Project/blob/main/smart_personal_study_coach_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Smart Personal Study Coach Agent
# **Team Genie** - Google AI Agents Capstone Project, Nov 2025
#
# ## Overview
# An AI-powered study coach that personalizes study plans, generates study content, creates quizzes, and provides feedback—powered solely by Google Gemini LLM.
#
# **Features:**
# - Understands user study goals and preferences
# - Creates summarized study notes and explanations
# - Generates personalized quizzes to test knowledge
# - Builds structured study schedules
# - Offers interactive feedback and encouragement

# %%
# !pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.11.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (2.32.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.10.5)

# %%
from google.colab import userdata
import google.generativeai as genai

GEMINI_API_KEY = userdata.get('GEMINI_API_KEY')
if not GEMINI_API_KEY:
    raise ValueError("GEMINI_API_KEY is missing or not set in Colab secrets!")

genai.configure(api_key=GEMINI_API_KEY)
gemini_model = genai.GenerativeModel("gemini-2.5-flash-lite")  # or change model if needed

# %%
def get_user_input():
    topic = input("Enter your study topic (e.g., Machine Learning, History): ").strip()
    duration_days = int(input("Enter number of study days: "))
    hours_per_day = float(input("Enter study hours per day: "))
    style = input("Preferred study style (e.g., summarized notes, detailed, quizzes): ").strip()
    return {
        "topic": topic,
        "duration_days": duration_days,
        "hours_per_day": hours_per_day,
        "style": style,
    }

# %%
def generate_study_plan(user_profile):
    prompt = f"""
    You are a personal study coach.
    The user wants to study {user_profile['topic']} over {user_profile['duration_days']} days, {user_profile['hours_per_day']} hours per day.
    Preferred style: {user_profile['style']}.
    Create a day-wise study schedule outlining topics to cover each day.
    Respond as a structured list with Day 1, Day 2, etc.
    """
    response = gemini_model.generate_content(prompt)
    return response.text.strip()

# %%
def generate_study_content(topic, style):
    prompt = f"""
    Generate {style} study notes about the topic: {topic}.
    Write in clear, concise language suitable for learners.
    """
    response = gemini_model.generate_content(prompt)
    return response.text.strip()

# %%
def generate_quiz(topic):
    prompt = f"""
    Create a 5-question quiz with answers about the topic: {topic}.
    Include multiple choice questions with options labeled A, B, C, D.
    Provide correct answers after the questions.
    """
    response = gemini_model.generate_content(prompt)
    return response.text.strip()

# %%
def generate_feedback(message):
    prompt = f"""
    You are a supportive study coach. Respond empathetically and provide encouragement.
    User says: "{message}"
    """
    response = gemini_model.generate_content(prompt)
    return response.text.strip()

# %%
def run_study_coach():
    user_profile = get_user_input()

    print("\nGenerating Study Plan...")
    plan = generate_study_plan(user_profile)
    print(plan)

    print("\nGenerating Study Content...")
    content = generate_study_content(user_profile['topic'], user_profile['style'])
    print(content)

    print("\nGenerating Quiz...")
    quiz = generate_quiz(user_profile['topic'])
    print(quiz)

    print("\nYou can now ask questions or share your feelings for feedback. Type 'exit' to quit.")
    while True:
        user_msg = input("You: ").strip()
        if user_msg.lower() == "exit":
            print("Good luck with your studies!")
            break

        feedback = generate_feedback(user_msg)
        print("Coach:", feedback)

# %%
run_study_coach()
# Out:
# Enter your study topic (e.g., Machine Learning, History): Java
# Enter number of study days: 3
# Enter study hours per day: 3
# Preferred study style (e.g., summarized notes, detailed, quizzes): Notes, concepts, quiz
#
# Generating Study Plan...
# Alright, let's get you set up for a focused 3-day Java study sprint! We'll break down the core concepts and keep it engaging with notes, explanations, and quick quizzes. Remember, consistency is key, and it's okay if you don't grasp everything perfectly on the first go.
#
# Here's your 3-day, 3-hour-per-day Java study schedule:
#
# ---
#
# ### **Day 1: Java Fundamentals & Basic Building Blocks (3 Hours)**
#
# **Goal:** Get a solid understanding of what Java is, its core syntax, and how to write your first programs.
#
# *   **Hour 1: Introduction to Java & Setting Up**
#     *   **Notes:**
#         *   What is Java? (Platform independence, "Write Once, Run Anywhere" - JVM, JRE, JDK)
#         *   Why learn Java? (Versatility, industry demand)
#         *   Setting up your environment:
#             *   Downloading and installing the JDK.
#             *   Choosing an IDE (Integrated Development Environment) - Recommending IntelliJ IDEA Community Edition, Eclipse, or VS Code with Java extensions.
#             *   Creating your first "Hello, World!" program.
#     *   **Concepts:**
#         *   Compiler vs. Interpreter (Java is compiled and interpreted)
#         *   Bytecode
#         *   Main Method (`public static void main(String[] args)`)
#         *   `System.out.println()`
#     *   **Quiz (5 questions):**
#         1.  What does JVM stand for?
#         2.  What is the main purpose of the JRE?
#         3.  Write down the exact syntax for printing "Java is fun!" to the console.
#         4.  True or False: Java is a purely interpreted language.
#         5.  What is the entry point for any Java application?
#
# *   **Hour 2: Variables, Data Types, and Operators**
#     *   **Notes:**
#         *   What are variables? (Named memory locations)
#         *   Primitive Data Types: `int`, `double`, `char`, `boolean`, `byte`, `short`, `long`, `float`.
#         *   Declaration and Initialization of variables.
#         *   Basic Arithmetic Operators: `+`, `-`, `*`, `/`, `%`.
#         *   Assignment Operators: `=`, `+=`, `-=`, `*=`, `/=`.
#         *   Increment/Decrement Operators: `++`, `--`.
#     *   **Concepts:**
#         *   Type Casting (Implicit and Explicit)
#         *   Operator Precedence
#     *   **Quiz (7 questions):**
#         1.  Declare an integer variable named `age` and initialize it to 25.
#         2.  What is the output of `System.out.println(10 / 3);`?
#         3.  What data type would you use to store a true/false value?
#         4.  What is the difference between `char` and `String`?
#         5.  If `x = 5`, what is the value of `x++` after the statement is executed?
#         6.  If `y = 10`, what is `y += 3;`?
#         7.  Write a statement to declare a floating-point variable `pi` and assign it the value of 3.14159.
#
# *   **Hour 3: Control Flow Statements (Part 1)**
#     *   **Notes:**
#         *   Conditional Statements: `if`, `else if`, `else`.
#         *   Comparison Operators: `==`, `!=`, `>`, `<`, `>=`, `<=`.
#         *   Logical Operators: `&&` (AND), `||` (OR), `!` (NOT).
#         *   `switch` statement.
#     *   **Concepts:**
#         *   Boolean expressions
#         *   Code blocking (`{}`)
#     *   **Quiz (8 questions):**
#         1.  Write an `if` statement that checks if a variable `score` is greater than or equal to 90.
#         2.  What is the output of `System.out.println(true && false);`?
#         3.  Write an `if-else` statement to print "Even" if a number is divisible by 2, and "Odd" otherwise.
#         4.  When would you typically use a `switch` statement over a series of `if-else if` statements?
#         5.  If `age = 18` and `isCitizen = true`, what is the result of `age >= 18 && isCitizen`?
#         6.  What operator checks for equality?
#         7.  What is the output of `System.out.println(false || true);`?
#         8.  Complete the `switch` statement to print "Monday" if `day = 1`.
#
# ---
#
# ### **Day 2: Object-Oriented Programming (OOP) Basics & Data Structures (3 Hours)**
#
# **Goal:** Understand the fundamental principles of OOP and how to work with common data structures.
#
# *   **Hour 1: Introduction to OOP & Classes/Objects**
#     *   **Notes:**
#         *   What is Object-Oriented Programming? (Abstractions, Modularity)
#         *   Key OOP Concepts: Encapsulation, Abstraction, Inheritance, Polymorphism (brief introduction).
#         *   Classes: Blueprints for objects.
#         *   Objects: Instances of classes.
#         *   Creating a simple class (e.g., `Car` with properties like `color`, `model`).
#         *   Creating objects from a class.
#         *   Instance variables (fields) and methods.
#     *   **Concepts:**
#         *   `new` keyword
#         *   Object State and Behavior
#     *   **Quiz (6 questions):**
#         1.  What is the fundamental difference between a class and an object?
#         2.  What keyword is used to create a new object in Java?
#         3.  If you have a `Dog` class, what would be an example of an object of that class?
#         4.  What are two key benefits of using OOP?
#         5.  List two common OOP principles (even if just by name).
#         6.  Define "instance variable" in the context of a class.
#
# *   **Hour 2: Constructors, Methods, and Getters/Setters**
#     *   **Notes:**
#         *   Constructors: Special methods for initializing objects. (Default constructor, parameterized constructors).
#         *   Defining and calling methods.
#         *   Method parameters and return types.
#         *   `this` keyword.
#         *   Encapsulation: Using `private` access modifiers.
#         *   Getters and Setters (accessor and mutator methods).
#     *   **Concepts:**
#         *   Method Overloading (briefly)
#         *   Access Modifiers (`public`, `private`)
#     *   **Quiz (7 questions):**
#         1.  What is the purpose of a constructor?
#         2.  Can a class have multiple constructors? If so, what is this called?
#         3.  What is the purpose of a "getter" method?
#         4.  Write a `setter` method for a `private` integer variable named `quantity` in a class.
#         5.  What does the `this` keyword refer to?
#         6.  If a method doesn't return any value, what is its return type?
#         7.  What is the output of calling a method `myMethod()` on an object `obj`?
#
# *   **Hour 3: Arrays & Basic Collections (ArrayList)**
#     *   **Notes:**
#         *   Arrays: Fixed-size collections of elements of the same type.
#         *   Declaring, initializing, and accessing array elements.
#         *   Iterating through arrays using loops.
#         *   Introduction to `ArrayList` from the `java.util` package.
#         *   Key `ArrayList` methods: `add()`, `get()`, `size()`, `remove()`.
#     *   **Concepts:**
#         *   Zero-based indexing
#         *   Dynamic vs. Static size
#     *   **Quiz (8 questions):**
#         1.  Declare an integer array named `numbers` of size 5.
#         2.  Initialize the first element of the `numbers` array (from question 1) to 10.
#         3.  Write a `for` loop to print all elements of an integer array `myArray`.
#         4.  What is the main difference between an array and an `ArrayList`?
#         5.  How would you add the string "Java" to an `ArrayList` named `languages`?
#         6.  How would you get the element at index 2 from an `ArrayList` named `items`?
#         7.  What method tells you how many elements are in an `ArrayList`?
#         8.  True or False: Arrays can change their size dynamically after creation.
#
# ---
#
# ### **Day 3: Control Flow (Part 2), Exception Handling & Basic Input/Output (3 Hours)**
#
# **Goal:** Enhance your control flow understanding, learn how to handle errors gracefully, and get data from the user.
#
# *   **Hour 1: Control Flow Statements (Part 2) & Loops**
#     *   **Notes:**
#         *   Looping Constructs: `for` loop (enhanced for-each loop).
#         *   `while` loop.
#         *   `do-while` loop.
#         *   `break` and `continue` statements.
#     *   **Concepts:**
#         *   Infinite loops
#         *   Loop termination conditions
#     *   **Quiz (7 questions):**
#         1.  Write a `while` loop that counts from 1 to 5.
#         2.  What is the output of the following code?
#             ```java
#             for (int i = 0; i < 5; i++) {
#                 if (i == 2) {
#                     break;
#                 }
#                 System.out.print(i + " ");
#             }
#             ```
#         3.  What is the main difference between a `while` loop and a `do-while` loop?
#         4.  When would you use the `continue` statement in a loop?
#         5.  Write an enhanced `for-each` loop to iterate through a `String` array called `names`.
#         6.  What is the output of:
#             ```java
#             int count = 0;
#             while (count < 3) {
#                 System.out.print("A ");
#                 count++;
#             }
#             ```
#         7.  Write a `do-while` loop that prints "Hello" at least once, even if the condition is initially false.
#
# *   **Hour 2: Exception Handling**
#     *   **Notes:**
#         *   What are exceptions? (Runtime errors that disrupt normal program flow).
#         *   Common exceptions: `NullPointerException`, `ArrayIndexOutOfBoundsException`, `ArithmeticException`.
#         *   The `try-catch` block: Handling exceptions.
#         *   `finally` block: Code that always executes.
#         *   `throw` and `throws` keywords (basic understanding).
#     *   **Concepts:**
#         *   Checked vs. Unchecked exceptions
#         *   Graceful error handling
#     *   **Quiz (6 questions):**
#         1.  What is the primary purpose of `try-catch` blocks?
#         2.  Give an example of a situation that would likely throw a `NullPointerException`.
#         3.  What is the purpose of the `finally` block in exception handling?
#         4.  If you have an array `arr` and you try to access `arr[10]` when its size is only 5, what exception would be thrown?
#         5.  Write a `try-catch` block to handle a potential `ArithmeticException` when dividing by a variable.
#         6.  What keyword is used to explicitly throw an exception?
#
# *   **Hour 3: Basic Input/Output & Review**
#     *   **Notes:**
#         *   Getting input from the user using the `Scanner` class (`java.util.Scanner`).
#         *   Reading different data types (`nextInt()`, `nextLine()`, `nextDouble()`, etc.).
#         *   Basic File I/O (brief mention, focus on console I/O).
#         *   **Review:** Quickly go over the key concepts from Days 1 and 2.
#         *   **Practice:** Attempt a few small coding problems that combine concepts from all three days.
#     *   **Concepts:**
#         *   Standard Input Stream (`System.in`)
#         *   Closing resources (`scanner.close()`)
#     *   **Quiz (5 questions):**
#         1.  What class do you use to get user input from the console?
#         2.  How would you read an integer entered by the user into a variable `userAge`?
#         3.  Why is it important to call `scanner.close()` after you're done with a `Scanner` object?
#         4.  Write a program snippet that prompts the user for their name and then prints "Hello, [name]!".
#         5.  What is the most fundamental principle of Java that allows it to run on different platforms? (This is a recap from Day 1!)
#
# ---
#
# **Tips for Success:**
#
# *   **Active Learning:** Don't just read. Type out the code examples, experiment with them, and try to break them.
# *   **Take Notes:** Use a notebook or a digital note-taking app to jot down key points, code snippets, and your own thoughts.
# *   **Practice, Practice, Practice:** The quizzes are just a starting point. Try to find more practice problems online (e.g., HackerRank, LeetCode - beginner level).
# *   **Breaks are Important:** Take short breaks every hour to avoid burnout.
# *   **Don't Get Discouraged:** Learning a new programming language takes time. Celebrate your small wins and keep going!
#
# Good luck with your Java study! Let me know how it goes.
#
# Generating Study Content...
# ## Java: Your Gateway to Building Powerful Applications
#
# These notes are designed to give you a solid foundation in Java, a versatile and widely-used programming language. We'll cover the core concepts, essential syntax, and practical applications.
#
# ---
#
# ### 1. What is Java?
#
# *   **High-Level, Object-Oriented Language:** Java is designed to be human-readable and structured around "objects," which represent real-world entities or concepts.
# *   **Platform Independent ("Write Once, Run Anywhere"):** This is Java's superpower! Once you compile your Java code, it can run on any device that has a Java Virtual Machine (JVM) installed, regardless of the operating system (Windows, macOS, Linux, etc.).
# *   **Robust and Secure:** Java has built-in features that help prevent common programming errors and enhance security.
# *   **Used for:** Web applications (server-side), mobile apps (Android), desktop applications, enterprise software, games, and more.
#
# ---
#
# ### 2. Core Concepts: Building Blocks of Java
#
# **a) Objects and Classes:**
#
# *   **Class:** A blueprint or template for creating objects. It defines the properties (data/attributes) and behaviors (methods/functions) that all objects of that type will have.
#     *   *Analogy:* A cookie cutter is a class; the cookies you make are objects.
# *   **Object:** An instance of a class. It's a concrete realization of the blueprint, with its own specific values for its properties.
#     *   *Analogy:* A specific cookie made using the cookie cutter.
#
# **b) Variables:**
#
# *   **Purpose:** To store data.
# *   **Types:**
#     *   **Primitive Data Types:** Represent single values.
#         *   `int`: Whole numbers (e.g., 10, -5).
#         *   `double`, `float`: Decimal numbers (e.g., 3.14, -0.5).
#         *   `char`: Single characters (e.g., 'A', 'z').
#         *   `boolean`: True or false values.
#         *   `byte`, `short`, `long`: Larger or smaller whole numbers than `int`.
#     *   **Reference Data Types:** Refer to objects (e.g., `String`, arrays, custom classes).
# *   **Declaration:** `dataType variableName;` (e.g., `int age;`)
# *   **Initialization:** `dataType variableName = initialValue;` (e.g., `String name = "Alice";`)
#
# **c) Methods:**
#
# *   **Purpose:** To perform actions or tasks. They represent the behaviors of objects.
# *   **Structure:**
#     ```java
#     returnType methodName(parameters) {
#         // Code to perform the task
#         return value; // If returnType is not void
#     }
#     ```
#     *   `returnType`: The type of data the method will return (e.g., `int`, `String`, `void` if it doesn't return anything).
#     *   `methodName`: A descriptive name for the method.
#     *   `parameters`: Input values the method accepts (optional).
# *   **Calling a Method:** `objectName.methodName(arguments);`
#
# **d) Control Flow Statements:**
#
# *   **Purpose:** To control the order in which statements are executed.
# *   **Conditional Statements:**
#     *   `if`: Executes code if a condition is true.
#     *   `else if`: Checks another condition if the previous `if` was false.
#     *   `else`: Executes code if all previous conditions were false.
#     *   `switch`: Selects one of many code blocks to execute based on a value.
# *   **Looping Statements:**
#     *   `for`: Repeats a block of code a fixed number of times.
#     *   `while`: Repeats a block of code as long as a condition is true.
#     *   `do-while`: Repeats a block of code at least once, then as long as a condition is true.
#
# **e) Data Structures:**
#
# *   **Arrays:** Ordered collections of elements of the same data type.
#     *   Declaration: `dataType[] arrayName;` or `dataType arrayName[];` (e.g., `int[] numbers;`)
#     *   Initialization: `arrayName = new dataType[size];` (e.g., `numbers = new int[5];`)
#     *   Accessing elements: `arrayName[index]` (e.g., `numbers[0]`) - **remember indices start at 0!**
# *   **`String`:** A special type for sequences of characters.
#     *   `String message = "Hello";`
#     *   Strings are immutable (cannot be changed after creation).
#
# ---
#
# ### 3. Getting Started with Java
#
# **a) The Java Development Kit (JDK):**
#
# *   **What it is:** A collection of tools needed to develop and run Java applications, including the compiler, debugger, and JVM.
# *   **Essential Components:**
#     *   **`javac` (Java Compiler):** Converts your human-readable `.java` files into machine-readable `.class` files (bytecode).
#     *   **`java` (Java Launcher):** Executes the compiled `.class` files using the JVM.
#
# **b) Your First Java Program: "Hello, World!"**
#
# ```java
# public class HelloWorld { // Defines a class named HelloWorld
#
#     public static void main(String[] args) { // The entry point of your program
#         System.out.println("Hello, World!"); // Prints text to the console
#     }
# }
# ```
#
# *   **`public class HelloWorld`:** Declares a public class named `HelloWorld`. Every Java program needs at least one class.
# *   **`public static void main(String[] args)`:** This is the `main` method. When you run a Java program, the JVM looks for and executes this method first.
#     *   `public`: Accessible from anywhere.
#     *   `static`: Belongs to the class itself, not a specific object.
#     *   `void`: The method doesn't return any value.
#     *   `String[] args`: An array of strings that can be used to pass command-line arguments to your program.
# *   **`System.out.println(...)`:** A standard method to print output to the console, followed by a newline.
#
# **c) Compiling and Running:**
#
# 1.  **Save:** Save the code above in a file named `HelloWorld.java`.
# 2.  **Compile:** Open a terminal or command prompt, navigate to the directory where you saved the file, and type:
#     `javac HelloWorld.java`
#     This will create `HelloWorld.class`.
# 3.  **Run:** In the same terminal, type:
#     `java HelloWorld`
#     You should see "Hello, World!" printed.
#
# ---
#
# ### 4. Object-Oriented Programming (OOP) Principles in Java
#
# **a) Encapsulation:**
#
# *   **Concept:** Bundling data (variables) and methods that operate on that data within a single unit (a class). It also involves controlling access to that data.
# *   **Keywords:** `public`, `private`, `protected` (access modifiers).
#     *   `public`: Accessible from anywhere.
#     *   `private`: Accessible only within the same class. This is key for data hiding.
# *   **Benefits:** Data protection, code organization, reusability.
#
# **b) Inheritance:**
#
# *   **Concept:** Allows a new class (child/subclass) to inherit properties and behaviors from an existing class (parent/superclass).
# *   **Keyword:** `extends`
# *   **Benefits:** Code reuse, creating hierarchies.
#     *   *Example:* A `Car` class could extend a `Vehicle` class.
#
# **c) Polymorphism:**
#
# *   **Concept:** "Many forms." The ability of an object to take on many forms. In Java, this often refers to the ability of methods to do different things based on the object that calls them.
# *   **Types:**
#     *   **Method Overloading:** Defining multiple methods with the same name but different parameter lists within the same class.
#     *   **Method Overriding:** A subclass provides its own implementation of a method that is already defined in its superclass.
# *   **Benefits:** Flexibility, extensibility.
#
# **d) Abstraction:**
#
# *   **Concept:** Hiding complex implementation details and showing only the essential features of an object.
# *   **Keywords:** `abstract` classes and `interface`s.
#     *   **Abstract Class:** A class that cannot be instantiated directly. It can have abstract methods (methods without implementation) and concrete methods.
#     *   **Interface:** A contract that defines a set of methods that a class must implement. It contains only abstract methods (and default/static methods since Java 8).
# *   **Benefits:** Simplifies complex systems, focuses on "what" rather than "how."
#
# ---
#
# ### 5. Key Java Features and Libraries
#
# *   **Java Collections Framework:** Provides interfaces and classes for storing and manipulating groups of objects (e.g., `ArrayList`, `HashMap`).
# *   **Input/Output (I/O):** For reading from and writing to files, network streams, etc.
# *   **Concurrency:** For building multi-threaded applications that can perform multiple tasks simultaneously.
# *   **Exception Handling:** A mechanism for dealing with runtime errors gracefully (using `try`, `catch`, `finally` blocks).
# *   **Java Standard Library (API):** A vast collection of pre-written code that provides ready-to-use functionalities for various tasks.
#
# ---
#
# ### Quiz Study Notes
#
# **1. What are the two fundamental components of Object-Oriented Programming (OOP) in Java?**
#     *   Classes and Objects
#
# **2. Explain the "Write Once, Run Anywhere" principle of Java.**
#     *   Java code is compiled into bytecode, which can be executed by the Java Virtual Machine (JVM) on any platform.
#
# **3. What is the purpose of the `main` method in a Java program?**
#     *   It's the entry point where the execution of a Java application begins.
#
# **4. Differentiate between a primitive data type and a reference data type in Java.**
#     *   Primitive types store actual values (e.g., `int`, `boolean`), while reference types store addresses to objects (e.g., `String`, arrays).
#
# **5. What is the difference between `==` and `.equals()` when comparing `String` objects?**
#     *   `==` compares object references (whether they point to the same object in memory).
#     *   `.equals()` compares the actual content (characters) of the `String` objects.
#
# **6. What are access modifiers in Java, and name at least two.**
#     *   Keywords that control the visibility and accessibility of classes, methods, and variables. Examples: `public`, `private`, `protected`.
#
# **7. What is method overloading?**
#     *   Defining multiple methods with the same name but different parameter lists within the same class.
#
# **8. What is method overriding?**
#     *   A subclass providing its own implementation of a method inherited from its superclass.
#
# **9. What is the role of the `javac` command?**
#     *   To compile Java source code (`.java` files) into bytecode (`.class` files).
#
# **10. What is the role of the `java` command?**
#     *   To execute compiled Java bytecode (`.class` files) using the JVM.
#
# **11. What are the benefits of encapsulation?**
#     *   Data hiding, improved security, code organization, and easier maintenance.
#
# **12. Name one common data structure in Java (besides arrays).**
#     *   `ArrayList`, `HashMap`, `LinkedList`, etc.
#
# **13. What does `System.out.println()` do?**
#     *   Prints text or variable values to the console, followed by a newline.
#
# **14. What are `abstract` classes and `interface`s used for in Java?**
#     *   Achieving abstraction by defining contracts and templates for classes, hiding implementation details.
#
# **15. What is an array index, and where does it start in Java?**
#     *   The position of an element within an array. It starts at 0.
#
# ---
#
# This is just the beginning of your Java journey! As you learn more, you'll explore advanced concepts, libraries, and frameworks that will empower you to build incredibly complex and sophisticated applications. Keep practicing, experiment with code, and have fun!
#
# Generating Quiz...
# Here is a 5-question quiz about Java:
#
# ---
#
# **Java Quiz**
#
# **1. Which of the following is NOT a primitive data type in Java?**
# A) `int`
# B) `String`
# C) `boolean`
# D) `char`
#
# **2. What keyword is used to define a class in Java?**
# A) `function`
# B) `class`
# C) `object`
# D) `new`
#
# **3. Which of the following statements correctly declares and initializes a String variable in Java?**
# A) `String myText = "Hello";`
# B) `String myText("Hello");`
# C) `string myText = "Hello";`
# D) `myText = String("Hello");`
#
# **4. What is the output of the following Java code snippet?**
# ```java
# public class Example {
#     public static void main(String[] args) {
#         int x = 5;
#         int y = 2;
#         System.out.println(x / y);
#     }
# }
# ```
# A) `2.5`
# B) `2`
# C) `3`
# D) An error
#
# **5. Which OOP (Object-Oriented Programming) concept in Java allows a class to inherit properties and methods from another class?**
# A) Polymorphism
# B) Encapsulation
# C) Abstraction
# D) Inheritance
#
# ---
#
# **Answers:**
#
# 1.  **B) `String`**
#     *   Explanation: `String` is an object in Java, not a primitive data type. Primitive types are `byte`, `short`, `int`, `long`, `float`, `double`, `char`, and `boolean`.
#
# 2.  **B) `class`**
#     *   Explanation: The `class` keyword is used to define a new class in Java.
#
# 3.  **A) `String myText = "Hello";`**
#     *   Explanation: This is the standard and correct way to declare and initialize a `String` variable in Java.
#
# 4.  **B) `2`**
#     *   Explanation: Both `x` and `y` are integers. When you divide two integers in Java, the result is also an integer, and any fractional part is truncated.
#
# 5.  **D) Inheritance**
#     *   Explanation: Inheritance is the mechanism by which a class can acquire the properties and behaviors of another class.
#
# You can now ask questions or share your feelings for feedback. Type 'exit' to quit.
# You: Exit
# Good luck with your studies!
